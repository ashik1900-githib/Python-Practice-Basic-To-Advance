# %% [markdown]
# ## Python Functions

# %% [markdown]
# A function is a block of code which only runs when it is called.
# A function can return data as a result.
# A function helps avoiding code repetition.

# %% [markdown]
# ### Creating a Function

# %%
def my_function():
  print("I am Md. Ashikur Rahman")
my_function()
# Out:
# I am Md. Ashikur Rahman

# %%
def my_function():
  print("I am Ashik")

my_function()
my_function()
my_function()
# Out:
# I am Ashik
# I am Ashik
# I am Ashik
