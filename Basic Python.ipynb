# %% [markdown]
# ### Addition

# %%
x= 50
y= 100
print("This is addition:",x+y)
# Out:
# This is addition: 150

# %% [markdown]
# ### Subtraction

# %%
x= 100
y= 50
print("This is Subtraction:",x-y)
# Out:
# This is Subtraction: 50

# %% [markdown]
# ### Multiplication

# %%
x= 100
y= 50
print("This is Multiplication:",x*y)
# Out:
# This is Multiplication: 5000

# %% [markdown]
# ### Division

# %%
x= 100
y= 50
print("This is Multiplication:",x//y)
# Out:
# This is Multiplication: 2

# %% [markdown]
# ### Power (Exponentiation)

# %%
x= 10
y= 5
print("This is Power (Exponentiation):",x**y)
# Out:
# This is Power (Exponentiation): 100000

# %% [markdown]
# ### Modulus

# %%
x= 10
y= 3
print("This is Power (Exponentiation):",x%y)
# Out:
# This is Power (Exponentiation): 1
